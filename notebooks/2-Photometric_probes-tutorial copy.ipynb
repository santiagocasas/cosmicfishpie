# %% [markdown]
# # CosmicFishPie

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
snscolors = sns.color_palette("colorblind")
envkey = 'OMP_NUM_THREADS'
print("The value of {:s} is: ".format(envkey), os.environ.get(envkey))
os.environ[envkey] = str(8)
print("The value of {:s} is: ".format(envkey), os.environ.get(envkey))

from cosmicfishpie.fishermatrix import cosmicfish
# Out:
# The value of OMP_NUM_THREADS is:  None
# The value of OMP_NUM_THREADS is:  8

# %% [markdown]
# # Table of Contents
#
# [Cosmological parameters](#cosmological-parameters)
#
# [Settings](#settings)
#
# [Photometric probe](#photometric-probes)
#
# [Fisher Matrix Photo](#fisher-matrix-photo)
#
# [Plot Fisher Matrices](#plot-fisher-matrices)

# %% [markdown]
# # Cosmological parameters

# %%
fiducial = {
    "Omegam": 0.32,
    "Omegab": 0.05,
    "h": 0.67,
    "ns": 0.96,
    "sigma8": 0.815584,
    "w0": -1.0,
    "wa": 0.0,
    "mnu": 0.06,
    "Neff": 3.044,
}

# %% [markdown]
# # Settings

# %%
options = {
    "accuracy": 1,
    "feedback": 1,
    "code": "camb",
    "specs_dir": "../survey_specifications/",
    "outroot": "photometric-probes",
    "survey_name": "Euclid",
    "survey_name_photo": "Euclid-Photometric-ISTF-Pessimistic",
    "camb_config_yaml": "../cosmicfishpie/configs/default_boltzmann_yaml_files/camb/mpvalidation.yaml",
    "cosmo_model": "w0waCDM",
}

# %%
observables = ["GCph", "WL"]

# %% [markdown]
# ### Pass options and settings to Cosmicfishpie
#
# We set the survey to `Euclid-Photometric-ISTF-Pessimistic` setting the default settings for the galaxy distributions, biases and modeling choices

# %%
cosmoFM_A = cosmicfish.FisherMatrix(
    fiducialpars=fiducial,
    options=options,
    observables=observables,
    cosmoModel=options["cosmo_model"],
    surveyName=options["survey_name"],
)
# Out:
# ****************************************************************
#    _____               _     _____     __
#   / ___/__  ___ __ _  (_)___/ __(_)__ / /
#  / /__/ _ \(_-</  ' \/ / __/ _// (_-</ _ \
#  \___/\___/___/_/_/_/_/\__/_/ /_/___/_//_/
#
# ****************************************************************
#  This is the new Python version of the CosmicFish code.
# ****************************************************************
# WARNING:root:share_delta_neff is deprecated in python interface, use delta_neff is only for backward compatibility with .ini files
# WARNING:root:share_delta_neff is deprecated in python interface, use delta_neff is only for backward compatibility with .ini files
# WARNING: specifications file : ../survey_specifications/Euclid-Spectroscopic-ISTF-Pessimistic.yaml not found!
# Using default specifications for spectroscopic: /home/santiago/CosmoProjects/cosmicfish_release/cosmicfishpie/cosmicfishpie/configs/default_survey_specifications/Euclid-Spectroscopic-ISTF-Pessimistic.yaml
#
#   -> Survey loaded:  Euclid-Spectroscopic-ISTF-Pessimistic
# WARNING: specifications file : ../survey_specifications/Euclid-Photometric-ISTF-Pessimistic.yaml not found!
# Using default specifications for photo: /home/santiago/CosmoProjects/cosmicfish_release/cosmicfishpie/cosmicfishpie/configs/default_survey_specifications/Euclid-Photometric-ISTF-Pessimistic.yaml
#
#   -> Survey loaded:  Euclid-Photometric-ISTF-Pessimistic
#
#   -> Computing cosmology at the fiducial point
# WARNING:root:share_delta_neff is deprecated in python interface, use delta_neff is only for backward compatibility with .ini files
#   ---> Cosmological functions obtained in:   31.89 s

# %%
options_b = {
    "accuracy": 1,
    "feedback": 1,
    "code": "class",
    "specs_dir": "../survey_specifications/",
    "outroot": "photometric-probes",
    "survey_name": "Euclid",
    "survey_name_photo": "Euclid-Photometric-ISTF-Pessimistic",
    "class_config_yaml": "../cosmicfishpie/configs/default_boltzmann_yaml_files/class/mpvalidation.yaml",
    "cosmo_model": "w0waCDM",
}

# %%
cosmoFM_B = cosmicfish.FisherMatrix(
    fiducialpars=fiducial,
    options=options_b,
    observables=observables,
    cosmoModel=options_b["cosmo_model"],
    surveyName=options_b["survey_name"],
)
# Out:
# ****************************************************************
#    _____               _     _____     __
#   / ___/__  ___ __ _  (_)___/ __(_)__ / /
#  / /__/ _ \(_-</  ' \/ / __/ _// (_-</ _ \
#  \___/\___/___/_/_/_/_/\__/_/ /_/___/_//_/
#
# ****************************************************************
#  This is the new Python version of the CosmicFish code.
# ****************************************************************
# WARNING: specifications file : ../survey_specifications/Euclid-Spectroscopic-ISTF-Pessimistic.yaml not found!
# Using default specifications for spectroscopic: /home/santiago/CosmoProjects/cosmicfish_release/cosmicfishpie/cosmicfishpie/configs/default_survey_specifications/Euclid-Spectroscopic-ISTF-Pessimistic.yaml
#
#   -> Survey loaded:  Euclid-Spectroscopic-ISTF-Pessimistic
# WARNING: specifications file : ../survey_specifications/Euclid-Photometric-ISTF-Pessimistic.yaml not found!
# Using default specifications for photo: /home/santiago/CosmoProjects/cosmicfish_release/cosmicfishpie/cosmicfishpie/configs/default_survey_specifications/Euclid-Photometric-ISTF-Pessimistic.yaml
#
#   -> Survey loaded:  Euclid-Photometric-ISTF-Pessimistic
#
#   -> Computing cosmology at the fiducial point
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cosmoFM_B = cosmicfish.FisherMatrix(
#       2     fiducialpars=fiducial,
#       3     options=options_b,
#       4     observables=observables,
#       5     cosmoModel=options_b["cosmo_model"],
#       6     surveyName=options_b["survey_name"],
#       7 )
#
# File ~/CosmoProjects/cosmicfish_release/cosmicfishpie/cosmicfishpie/fishermatrix/cosmicfish.py:142, in FisherMatrix.__init__(self, options, specifications, observables, freepars, extfiles, fiducialpars, photobiaspars, photopars, spectrononlinearpars, spectrobiaspars, IApars, IMbiaspars, PShotpars, surveyName, cosmoModel, latexnames, parallel, parallel_cpus)
#     139     print("****************************************************************")
#     140     sys.stdout.flush()
# --> 142 cfg.init(
#     143     options=options,
#     144     specifications=specifications,
#     145     observables=observables,
#     146     freepars=freepars,
#     147     extfiles=extfiles,
#     148     fiducialpars=fiducialpars,
#     149     photobiaspars=photobiaspars,
#     150     photopars=photopars,
#     151     IApars=IApars,
#     152     spectrononlinearpars=spectrononlinearpars,
#     153     spectrobiaspars=spectrobiaspars,
#     154     IMbiaspars=IMbiaspars,
#     155     PShotpars=PShotpars,
#     156     surveyName=surveyName,
#     157     cosmoModel=cosmoModel,
#     158     latexnames=latexnames,
#     159 )
#     160 self.settings = deepcopy(cfg.settings)
#     161 self.specs = deepcopy(cfg.specs)
#
# File ~/CosmoProjects/cosmicfish_release/cosmicfishpie/cosmicfishpie/configs/config.py:655, in init(options, specifications, observables, freepars, extfiles, fiducialpars, photobiaspars, photopars, IApars, PShotpars, spectrobiaspars, spectrononlinearpars, IMbiaspars, surveyName, cosmoModel, latexnames)
#     649 upt.time_print(
#     650     feedback_level=feed_lvl,
#     651     min_level=1,
#     652     text="-> Computing cosmology at the fiducial point",
#     653 )
#     654 tcosmo1 = time()
# --> 655 fiducialcosmo = cosmology.cosmo_functions(fiducialparams, input_type)
#     656 tcosmo2 = time()
#     657 upt.time_print(
#     658     feedback_level=feed_lvl,
#     659     min_level=1,
#    (...)
#     662     time_fin=tcosmo2,
#     663 )
#
# File ~/CosmoProjects/cosmicfish_release/cosmicfishpie/cosmicfishpie/cosmology/cosmology.py:1574, in cosmo_functions.__init__(self, cosmopars, input)
#    1572     self.cosmopars = externalinput.cosmopars
#    1573 elif input == "class":
# -> 1574     classresults = boltzmann_code(cosmopars, code="class")
#    1575     self.code = "class"
#    1576     self.results = classresults.results
#
# File ~/CosmoProjects/cosmicfish_release/cosmicfishpie/cosmicfishpie/cosmology/cosmology.py:124, in boltzmann_code.__init__(self, cosmopars, code)
#     122 elif code == "class":
#     123     self.boltzmann_classpars = cfg.boltzmann_classpars
# --> 124     from classy import Class
#     126     self.class_setparams(self.cosmopars)
#     127     self.class_results(Class)
#
# ModuleNotFoundError: No module named 'classy'

# %% [markdown]
# # Photometric probes

# %% [markdown]
# ## 3x2pt Angular Power Spectrum Observable

# %% [markdown]
# The 3x2pt function is the auto- and cross-correlation of observables X, Y = {L, G},  which can be combined in 3 times the 2pt-function of:
# Lensing-Lensing, Galaxy-Lensing and Galaxy-Galaxy
#
# $$
# C_{ij}^{XY}(\ell) = \int^{z_{max}}_{z_{min}} \!\!\!\!\! dz  \frac{W_{i}^{X}(z) W_{j}^{Y}(z)}{H(z)r^{2}(z)} P_{\delta \delta} \! \left[ \frac{\ell+1/2}{r(z)},z \right] +N_{ij}^{XY}(\ell)
# $$
#
# where the cosmic shear window function is given by:
#
# $$
# W_i^{\gamma}(z) = \frac{3}{2} \, H_0^2 \, \Omega_m \,  (1+z) \, r(z) \int_z^{z_{max}}dz^\prime \,
#     %\niof(z')
#     n_i(z^\prime)
#     \left[1- \frac{r(z)}{r(z^\prime)}\right]~
# $$
#
# and the estimated number density of galaxies in each bin is given by:
#
# $$
# n_i(z) = \frac{\int_{z_i^-}^{z_i^+} dz_p n(z) p_{ph}(z_p|z)}{\int_{z_{min}}^{z_{max}}dz \int_{z_i^-}^{z_i^+}dz_p n(z) p_{ph}(z_p|z)}~
# $$
#
# which is a convolution of the theoretical mean number density with a photometric redshift error distribution:
#
# $$
# p_{ph}(z_p|z) = \frac{1-f_{out}}{\sqrt{2\pi}\sigma_b(1+z)} \exp\left\{-\frac{1}{2}\left[\frac{z-c_bz_p-z_b}{\sigma_b(1+z)}\right]^2\right\} \\ + \frac{f_{out}}{\sqrt{2\pi}\sigma_0(1+z)} \exp\left\{-\frac{1}{2}\left[\frac{z-c_0z_p-z_0}{\sigma_0(1+z)}\right]^2\right\}
# $$
#
# The full lensing function is given by the addition of cosmic shear and intrinsic alignment, which takes the following form:
#
# $$
# W_{i}^{L}(z) = W_{i}^{\gamma}(z) - W_{i}^\mathrm{IA}(z)
# $$
#
# Moreover for IA and for photometric Galaxy clustering, the window function takes the simple form:
#
# $$
# W_{i}^\mathrm{IA}(z) = \mathcal{A}_\mathrm{IA} \mathcal{C}_\mathrm{IA}\Omega_{m,0} \frac{\mathcal{F}_\mathrm{IA}(z)}{D(z)} n_i(z) H(z)\\
# W_{i}^{G}(z) = n_i(z) H(z)\, b_i(z)
# $$
#
# Here, $b_i(z)$ is the galaxy bias (the ratio between the density contrast of galaxies and dark matter).

# %%
print(cosmoFM_A.photopars)
print(cosmoFM_A.photobiaspars)
print(cosmoFM_A.IApars)
# Out:
# {'fout': 0.1, 'co': 1, 'cb': 1, 'sigma_o': 0.05, 'sigma_b': 0.05, 'zo': 0.1, 'zb': 0.0}
# {'bias_model': 'binned', 'b1': np.float64(1.0997727037892875), 'b2': np.float64(1.220245876862528), 'b3': np.float64(1.2723993083933989), 'b4': np.float64(1.316624471897739), 'b5': np.float64(1.35812370570578), 'b6': np.float64(1.3998214171814918), 'b7': np.float64(1.4446452851824907), 'b8': np.float64(1.4964959071110084), 'b9': np.float64(1.5652475842498528), 'b10': np.float64(1.7429859437184225)}
# {'IA_model': 'eNLA', 'AIA': 1.72, 'betaIA': 2.17, 'etaIA': -0.41}

# %% [markdown]
# ## Compute the Photometric angular power spectrum $C(\ell)$

# %%
from cosmicfishpie.LSSsurvey import photo_obs as phobs

# %% [markdown]
# Declare an instance of the class and compute the angular power spectrum

# %%
photo_Cls = phobs.ComputeCls(
    cosmoFM_A.fiducialcosmopars, cosmoFM_A.photopars, cosmoFM_A.IApars, cosmoFM_A.photobiaspars
)
phCls_A = photo_Cls.compute_all()

# %% [markdown]
# ## Extract the window functions from CosmicFishPie

# %%
zz = np.linspace(0.001, 2.5, 250)  ## Euclid specs are only defined up to z=3.

# %%
photo_Cls.binrange
# Out:
# {'GCph': range(1, 11), 'WL': range(1, 11)}

# %%
## Window function class for photometric probes
window = photo_Cls.window

# %% [markdown]
# ### Plot galaxy number density at each of the bins

# %%
color = iter(snscolors)
plt.figure(figsize=(10, 7))
plt.plot(zz, window.dNdz(zz), label=r"$n(z)$", color="k", lw=3, ls="--")
for ind in photo_Cls.binrange['WL']:
    c = next(color)
    plt.plot(zz, window.ngal_photoz(zz, ind, obs="WL"), label=r"$n^{ph}_{%i}$" % ind, color=c)
    plt.plot(zz, window.n_i(zz, ind), ls=":")  # label=r'dNi bin-'+str(ind), color=c)
plt.xlabel(r"$z$", fontsize=25)
plt.ylabel(r"$n(z)$", fontsize=25)
plt.legend(bbox_to_anchor=(1.04, 0.5), loc="center left", fontsize=20)

# %% [markdown]
# ### Plot radial window functions for each of the probes

# %%
color = iter(snscolors)
fig, axs = plt.subplots(3, 1, figsize=(13, 9))
plt.figure(figsize=(10, 8))
for ind in photo_Cls.binrange['GCph']:
    c = next(color)
    axs[0].plot(zz, photo_Cls.genwindow(zz, "GCph", ind)[0], lw=2.0, color=c)
color = iter(snscolors)
for ind in photo_Cls.binrange['WL']:
    c = next(color)
    axs[1].plot(zz, photo_Cls.genwindow(zz, "WL", ind)[0], lw=3.0, color=c)
    axs[2].plot(zz, photo_Cls.genwindow(zz, "WL", ind)[1], lw=3.0, color=c, label=r"bin %s" % ind)
axs[0].set_xlabel(r"$z$", fontsize=20)

axs[0].set_ylabel(r"$W_i^{G}(z)$", fontsize=20)
axs[1].set_ylabel(r"$W_i^{\gamma}(z)$", fontsize=20)
axs[2].set_ylabel(r"$W_i^\mathrm{IA}(z)$", fontsize=20)
axs[0].minorticks_on()
axs[1].minorticks_on()
axs[2].minorticks_on()
fig.legend(bbox_to_anchor=(1.04, 0.5), loc="center left", fontsize=20)

# %% [markdown]
# ## Finally plot the 3x2pt $C^{XY}_{ij}(\ell)$

# %%
# Accessing LSS cls
cls = photo_Cls.result
ell = cls["ells"]
norm = ell * (ell + 1) / (2 * np.pi)

color = iter(snscolors)
fig, axs = plt.subplots(3, 1, figsize=(21, 25), sharex=True)
for bin1, bin2 in zip([1, 2, 4, 6, 10], [2, 2, 5, 7, 10]):
    c = next(color)
    axs[0].loglog(
        ell,
        norm * cls["GCph " + str(bin1) + "xGCph " + str(bin2)],
        color=c,
        label="GxG i=" + str(bin1) + ", j=" + str(bin2),
        ls="-",
        lw=2.1,
    )
    axs[1].loglog(
        ell,
        norm * cls["WL " + str(bin1) + "xWL " + str(bin2)],
        color=c,
        label="LxL i=" + str(bin1) + ", j=" + str(bin2),
        ls="-",
        lw=2.1,
    )
    corr = norm * cls["WL " + str(bin1) + "xGCph " + str(bin2)]
    if np.mean(corr) < 0:
        ls = "--"
    else:
        ls = "-"
    axs[2].loglog(
        ell, abs(corr), color=c, label="LxG i=" + str(bin1) + ", j=" + str(bin2), ls=ls, lw=2.1
    )
axs[0].set_ylabel(r"$\ell(\ell+1)C_{ij}^{GG}(\ell)/2\pi$", fontsize=35)
axs[0].legend(bbox_to_anchor=(1.04, 0.5), loc="center left", fontsize=25)
axs[1].set_ylabel(r"$\ell(\ell+1)C_{ij}^{LL}(\ell)/2\pi$", fontsize=35)
axs[1].legend(bbox_to_anchor=(1.04, 0.5), loc="center left", fontsize=25)
axs[2].set_ylabel(r"$\ell(\ell+1)C_{ij}^{LG}(\ell)/2\pi$", fontsize=35)
axs[2].legend(bbox_to_anchor=(1.04, 0.5), loc="center left", fontsize=25)

axs[2].set_xlim(10, 740)
axs[2].set_xlabel(r"Multipole $\ell$", fontsize=35)
fig.subplots_adjust(hspace=0.0)

[ax.tick_params(which="major", length=15, width=2, direction="in") for ax in axs]
[ax.tick_params(which="minor", length=8, width=1, direction="in") for ax in axs]
[ax.minorticks_on() for ax in axs]
[ax.tick_params(axis="both", which="major", labelsize=21) for ax in axs]
[ax.tick_params(axis="both", which="minor", labelsize=15) for ax in axs]

plt.show()

# %% [markdown]
# # Fisher Matrix Photo

# %%
from cosmicfishpie.fishermatrix.cosmicfish import FisherMatrix

# %%
#Define the observables you are interested in
observables = [['GCph'],['WL'],['GCph','WL']]

runRootName = "LCDM_5p_symb"
#Input options for CosmicFish (global options)
options = {'accuracy': 1,
           #'outroot': 'LCDM_camb_int-full-HMc2020',
           'results_dir': 'results/',
           'derivatives': '3PT',
           'nonlinear': True,
           'feedback': 1,
           'survey_name': 'Euclid',
           'specs_dir' : '../cosmicfishpie/configs/default_survey_specifications/',
           #'survey_name_photo': 'Euclid-Photometric-ISTF-Pessimistic',
           #'survey_name_spectro': 'Euclid-Spectroscopic-'+'ISTF-Pessimistic',
           'cosmo_model' : 'LCDM',
           'code': 'symbolic',
           #'camb_config_yaml':'../boltzmann_yaml_files/camb/default.yaml'
           }

specas = {
    'ISTF-Pessimistic': {'specs_dir': '../cosmicfishpie/configs/default_survey_specifications/'},
}

#Internally Cosmicfish converts these Parameters to the coresponding parameters in CAMB or CLASS 
fiducial = {
            "Omegam":0.3186,
            #'omch2':0.121259,
            #"ombh2":0.0227,
            "Omegab": 0.0491989,
            #"w0":-1.0,
            #"wa":0.,
            "h":0.6737,
            "ns":0.966,
            #"logAs":3.04,
            "sigma8" : 0.81,
            #"mnu":0.06,
            #"Neff":3.043
            }

#Parameters to be varied and analyzed and their percentage variation for numerical derivatives
# IA params and photometric galaxy bias are added automatically to these parameters
freepars = {
            #'omch2': 0.01,
            #'ombh2': 0.01,
            #'logAs' : 0.01,
            #'w0': 0.01,
            #'wa': 0.01,
            'Omegab':0.01,
            'h': 0.01,
            'ns': 0.01,
            'sigma8': 0.01,
            'Omegam':0.01,
            }

# %%
observables
# Out:
# [['GCph'], ['WL'], ['GCph', 'WL']]

# %%
cosmoFM = {}
fish_photo = {}
for obse in observables:
    string_obse = '-'.join(obse)
    cosmoFM[string_obse] = cosmicfish.FisherMatrix(fiducialpars=fiducial,    #Pass the above dictionaries to cosmoFM, the main cosmicfish class
                                      freepars=freepars,
                                      options=options, 
                                      observables=obse,  
                                      cosmoModel=options['cosmo_model']
                                  )

    fish_photo[string_obse] = cosmoFM[string_obse].compute()
# Out:
# ****************************************************************
#    _____               _     _____     __
#   / ___/__  ___ __ _  (_)___/ __(_)__ / /
#  / /__/ _ \(_-</  ' \/ / __/ _// (_-</ _ \
#  \___/\___/___/_/_/_/_/\__/_/ /_/___/_//_/
#
# ****************************************************************
#  This is the new Python version of the CosmicFish code.
# ****************************************************************
#
#   -> Survey loaded:  Euclid-Spectroscopic-ISTF-Pessimistic
#
#   -> Survey loaded:  Euclid-Photometric-ISTF-Pessimistic
#
#   -> Computing cosmology at the fiducial point
#
#   ---> Cosmological functions obtained in:   0.21 s
#
# In class: FisherMatrix  ----> Computing photo Fisher matrix
#
# Computing fiducial
#
# Fiducial generated in 1.37 s
#
# Noise added to fiducial
#
# Noisy Cls generated in 0.00 s
#
# Computed covariance matrix
#
# Covmat of Cls generated in 0.30 s
#
# Total calculation in 1.67 s
# >> computing derivs >>
#
#   +++ Computing derivative on Omegab
#
# In class: derivatives  Derivative on Omegab done! in :  3.03 s
#
#   +++ Computing derivative on h
#
# In class: derivatives  Derivative on h done! in :  3.04 s
#
#   +++ Computing derivative on ns
#
# In class: derivatives  Derivative on ns done! in :  3.09 s
#
#   +++ Computing derivative on sigma8
#
# In class: derivatives  Derivative on sigma8 done! in :  3.08 s
#
#   +++ Computing derivative on Omegam
#
# In class: derivatives  Derivative on Omegam done! in :  2.97 s
#
#   +++ Computing derivative on b1
#
# In class: derivatives  Derivative on b1 done! in :  2.62 s
#
#   +++ Computing derivative on b2
#
# In class: derivatives  Derivative on b2 done! in :  2.75 s
#
#   +++ Computing derivative on b3
#
# In class: derivatives  Derivative on b3 done! in :  2.66 s
#
#   +++ Computing derivative on b4
#
# In class: derivatives  Derivative on b4 done! in :  2.61 s
#
#   +++ Computing derivative on b5
#
# In class: derivatives  Derivative on b5 done! in :  2.66 s
#
#   +++ Computing derivative on b6
#
# In class: derivatives  Derivative on b6 done! in :  2.66 s
#
#   +++ Computing derivative on b7
#
# In class: derivatives  Derivative on b7 done! in :  2.67 s
#
#   +++ Computing derivative on b8
#
# In class: derivatives  Derivative on b8 done! in :  2.58 s
#
#   +++ Computing derivative on b9
#
# In class: derivatives  Derivative on b9 done! in :  2.62 s
#
#   +++ Computing derivative on b10
#
# In class: derivatives  Derivative on b10 done! in :  2.64 s
#
# In class: PhotoCov  -->> Derivatives computed in   41.69 s
#
# In class: FisherMatrix  Computing Fisher matrix
#
#   Finished calculation of Fisher Matrix for ['GCph'] in:   0.02 s
#
#   Fisher matrix calculation finished in   43.84 s
#
#   Fisher matrix exported: results//CosmicFish_v1.2.5_default_run_GCph_fishermatrix.txt
#
#
# In class: FisherMatrix  CosmicFish settings and Survey specifications exported: results//CosmicFish_v1.2.5_default_run_GCph_fishermatrix_specifications.dat
# ****************************************************************
#    _____               _     _____     __
#   / ___/__  ___ __ _  (_)___/ __(_)__ / /
#  / /__/ _ \(_-</  ' \/ / __/ _// (_-</ _ \
#  \___/\___/___/_/_/_/_/\__/_/ /_/___/_//_/
#
# ****************************************************************
#  This is the new Python version of the CosmicFish code.
# ****************************************************************
#
#   -> Survey loaded:  Euclid-Spectroscopic-ISTF-Pessimistic
#
#   -> Survey loaded:  Euclid-Photometric-ISTF-Pessimistic
#
#   -> Computing cosmology at the fiducial point
#
#   ---> Cosmological functions obtained in:   0.20 s
#
# In class: FisherMatrix  ----> Computing photo Fisher matrix
#
# Computing fiducial
#
# Fiducial generated in 3.58 s
#
# Noise added to fiducial
#
# Noisy Cls generated in 0.00 s
#
# Computed covariance matrix
#
# Covmat of Cls generated in 0.30 s
#
# Total calculation in 3.88 s
# >> computing derivs >>
#
#   +++ Computing derivative on Omegab
#
# In class: derivatives  Derivative on Omegab done! in :  7.68 s
#
#   +++ Computing derivative on h
#
# In class: derivatives  Derivative on h done! in :  7.67 s
#
#   +++ Computing derivative on ns
#
# In class: derivatives  Derivative on ns done! in :  7.65 s
#
#   +++ Computing derivative on sigma8
#
# In class: derivatives  Derivative on sigma8 done! in :  7.65 s
#
#   +++ Computing derivative on Omegam
#
# In class: derivatives  Derivative on Omegam done! in :  7.68 s
#
#   +++ Computing derivative on AIA
#
# In class: derivatives  Derivative on AIA done! in :  7.23 s
#
#   +++ Computing derivative on betaIA
#
# In class: derivatives  Derivative on betaIA done! in :  7.38 s
#
#   +++ Computing derivative on etaIA
#
# In class: derivatives  Derivative on etaIA done! in :  7.50 s
#
# In class: PhotoCov  -->> Derivatives computed in   60.45 s
#
# In class: FisherMatrix  Computing Fisher matrix
#
#   Finished calculation of Fisher Matrix for ['WL'] in:   0.01 s
#
#   Fisher matrix calculation finished in   64.80 s
#
#   Fisher matrix exported: results//CosmicFish_v1.2.5_default_run_WL_fishermatrix.txt
#
#
# In class: FisherMatrix  CosmicFish settings and Survey specifications exported: results//CosmicFish_v1.2.5_default_run_WL_fishermatrix_specifications.dat
# ****************************************************************
#    _____               _     _____     __
#   / ___/__  ___ __ _  (_)___/ __(_)__ / /
#  / /__/ _ \(_-</  ' \/ / __/ _// (_-</ _ \
#  \___/\___/___/_/_/_/_/\__/_/ /_/___/_//_/
#
# ****************************************************************
#  This is the new Python version of the CosmicFish code.
# ****************************************************************
#
#   -> Survey loaded:  Euclid-Spectroscopic-ISTF-Pessimistic
#
#   -> Survey loaded:  Euclid-Photometric-ISTF-Pessimistic
#
#   -> Computing cosmology at the fiducial point
#
#   ---> Cosmological functions obtained in:   0.21 s
#
# In class: FisherMatrix  ----> Computing photo Fisher matrix
#
# Computing fiducial
#
# Fiducial generated in 4.42 s
#
# Noise added to fiducial
#
# Noisy Cls generated in 0.00 s
#
# Computed covariance matrix
#
# Covmat of Cls generated in 1.15 s
#
# Total calculation in 5.57 s
# >> computing derivs >>
#
#   +++ Computing derivative on Omegab
#
# In class: derivatives  Derivative on Omegab done! in :  9.38 s
#
#   +++ Computing derivative on h
#
# In class: derivatives  Derivative on h done! in :  9.30 s
#
#   +++ Computing derivative on ns
#
# In class: derivatives  Derivative on ns done! in :  9.24 s
#
#   +++ Computing derivative on sigma8
#
# In class: derivatives  Derivative on sigma8 done! in :  9.28 s
#
#   +++ Computing derivative on Omegam
#
# In class: derivatives  Derivative on Omegam done! in :  9.26 s
#
#   +++ Computing derivative on b1
#
# In class: derivatives  Derivative on b1 done! in :  8.84 s
#
#   +++ Computing derivative on b2
#
# In class: derivatives  Derivative on b2 done! in :  8.86 s
#
#   +++ Computing derivative on b3
#
# In class: derivatives  Derivative on b3 done! in :  8.78 s
#
#   +++ Computing derivative on b4
#
# In class: derivatives  Derivative on b4 done! in :  8.90 s
#
#   +++ Computing derivative on b5
#
# In class: derivatives  Derivative on b5 done! in :  8.92 s
#
#   +++ Computing derivative on b6
#
# In class: derivatives  Derivative on b6 done! in :  8.79 s
#
#   +++ Computing derivative on b7
#
# In class: derivatives  Derivative on b7 done! in :  8.97 s
#
#   +++ Computing derivative on b8
#
# In class: derivatives  Derivative on b8 done! in :  8.90 s
#
#   +++ Computing derivative on b9
#
# In class: derivatives  Derivative on b9 done! in :  8.83 s
#
#   +++ Computing derivative on b10
#
# In class: derivatives  Derivative on b10 done! in :  8.98 s
#
#   +++ Computing derivative on AIA
#
# In class: derivatives  Derivative on AIA done! in :  8.75 s
#
#   +++ Computing derivative on betaIA
#
# In class: derivatives  Derivative on betaIA done! in :  8.86 s
#
#   +++ Computing derivative on etaIA
#
# In class: derivatives  Derivative on etaIA done! in :  8.97 s
#
# In class: PhotoCov  -->> Derivatives computed in   161.81 s
#
# In class: FisherMatrix  Computing Fisher matrix
#
#   Finished calculation of Fisher Matrix for ['GCph', 'WL'] in:   0.09 s
#
#   Fisher matrix calculation finished in   167.93 s
#
#   Fisher matrix exported: results//CosmicFish_v1.2.5_default_run_GCphWL_fishermatrix.txt
#
#
# In class: FisherMatrix  CosmicFish settings and Survey specifications exported: results//CosmicFish_v1.2.5_default_run_GCphWL_fishermatrix_specifications.dat

# %% [markdown]
# # Plot Fisher Matrices

# %%
import os
from cosmicfishpie.analysis import fisher_plot_analysis as cfa
import cosmicfishpie.analysis.fishconsumer as fco

# %%
print(os.path.isfile(fish_photo['GCph-WL'].file_name))
print(os.path.isfile(fish_photo['GCph'].file_name))
print(os.path.isfile(fish_photo['WL'].file_name))
# Out:
# True
# True
# True

# %%
param_names = fish_photo['GCph-WL'].get_param_names()
param_names
# Out:
# ['Omegab',
#  'h',
#  'ns',
#  'sigma8',
#  'Omegam',
#  'b1',
#  'b2',
#  'b3',
#  'b4',
#  'b5',
#  'b6',
#  'b7',
#  'b8',
#  'b9',
#  'b10',
#  'AIA',
#  'betaIA',
#  'etaIA']

# %%
fishers_analyze = cfa.CosmicFish_FisherAnalysis(fisher_list=[fish_photo['GCph'], 
                                                             fish_photo['WL'], 
                                                             fish_photo['GCph-WL']])

# %%
fishers_analyze.compare_fisher_results()
# Out:
# ----
# Fisher Name:  CosmicFish_v1.2.5_default_run_GCph_fishermatrix
# Fisher FoM in Omegab,h: 20765.771
# Parameter Omegab    , fiducial:    0.049, 1-sigma error:   0.0032, percent error:      6.4%
# Parameter h         , fiducial:    0.674, 1-sigma error:   0.0314, percent error:      4.7%
# Parameter ns        , fiducial:    0.966, 1-sigma error:   0.0306, percent error:      3.2%
# Parameter sigma8    , fiducial:    0.810, 1-sigma error:   0.0123, percent error:      1.5%
# Parameter Omegam    , fiducial:    0.319, 1-sigma error:   0.0079, percent error:      2.5%
# Parameter b1        , fiducial:    1.100, 1-sigma error:   0.0258, percent error:      2.3%
# Parameter b2        , fiducial:    1.220, 1-sigma error:   0.0287, percent error:      2.3%
# Parameter b3        , fiducial:    1.272, 1-sigma error:   0.0290, percent error:      2.3%
# Parameter b4        , fiducial:    1.317, 1-sigma error:   0.0294, percent error:      2.2%
# Parameter b5        , fiducial:    1.358, 1-sigma error:   0.0297, percent error:      2.2%
# Parameter b6        , fiducial:    1.400, 1-sigma error:   0.0302, percent error:      2.2%
# Parameter b7        , fiducial:    1.445, 1-sigma error:   0.0307, percent error:      2.1%
# Parameter b8        , fiducial:    1.496, 1-sigma error:   0.0314, percent error:      2.1%
# Parameter b9        , fiducial:    1.565, 1-sigma error:   0.0325, percent error:      2.1%
# Parameter b10       , fiducial:    1.743, 1-sigma error:   0.0360, percent error:      2.1%
# ----
# Fisher Name:  CosmicFish_v1.2.5_default_run_WL_fishermatrix
# Fisher FoM in Omegab,h: 1810.902
# Parameter Omegab    , fiducial:    0.049, 1-sigma error:   0.0221, percent error:     45.0%
# Parameter h         , fiducial:    0.674, 1-sigma error:   0.1307, percent error:     19.4%
# Parameter ns        , fiducial:    0.966, 1-sigma error:   0.0294, percent error:      3.0%
# Parameter sigma8    , fiducial:    0.810, 1-sigma error:   0.0080, percent error:      1.0%
# Parameter Omegam    , fiducial:    0.319, 1-sigma error:   0.0063, percent error:      2.0%
# Parameter AIA       , fiducial:    1.720, 1-sigma error:   3.9533, percent error:    229.8%
# Parameter betaIA    , fiducial:    2.170, 1-sigma error:   1.0547, percent error:     48.6%
# Parameter etaIA     , fiducial:   -0.410, 1-sigma error:   2.5265, percent error:    616.2%
# ----
# Fisher Name:  CosmicFish_v1.2.5_default_run_GCphWL_fishermatrix
# Fisher FoM in Omegab,h: 42069.360
# Parameter Omegab    , fiducial:    0.049, 1-sigma error:   0.0026, percent error:      5.3%
# Parameter h         , fiducial:    0.674, 1-sigma error:   0.0198, percent error:      2.9%
# Parameter ns        , fiducial:    0.966, 1-sigma error:   0.0086, percent error:      0.9%
# Parameter sigma8    , fiducial:    0.810, 1-sigma error:   0.0034, percent error:      0.4%
# Parameter Omegam    , fiducial:    0.319, 1-sigma error:   0.0028, percent error:      0.9%
# Parameter b1        , fiducial:    1.100, 1-sigma error:   0.0069, percent error:      0.6%
# Parameter b2        , fiducial:    1.220, 1-sigma error:   0.0065, percent error:      0.5%
# Parameter b3        , fiducial:    1.272, 1-sigma error:   0.0065, percent error:      0.5%
# Parameter b4        , fiducial:    1.317, 1-sigma error:   0.0065, percent error:      0.5%
# Parameter b5        , fiducial:    1.358, 1-sigma error:   0.0066, percent error:      0.5%
# Parameter b6        , fiducial:    1.400, 1-sigma error:   0.0067, percent error:      0.5%
# Parameter b7        , fiducial:    1.445, 1-sigma error:   0.0070, percent error:      0.5%
# Parameter b8        , fiducial:    1.496, 1-sigma error:   0.0068, percent error:      0.5%
# Parameter b9        , fiducial:    1.565, 1-sigma error:   0.0069, percent error:      0.4%
# Parameter b10       , fiducial:    1.743, 1-sigma error:   0.0075, percent error:      0.4%
# Parameter AIA       , fiducial:    1.720, 1-sigma error:   1.4266, percent error:     82.9%
# Parameter betaIA    , fiducial:    2.170, 1-sigma error:   0.3455, percent error:     15.9%
# Parameter etaIA     , fiducial:   -0.410, 1-sigma error:   0.9260, percent error:    225.9%

# %%
truth_values = fish_photo['GCph-WL'].get_param_names_fiducial_dict()
truth_values
# Out:
# {'Omegab': np.float64(0.049199),
#  'h': np.float64(0.6737),
#  'ns': np.float64(0.966),
#  'sigma8': np.float64(0.81),
#  'Omegam': np.float64(0.3186),
#  'b1': np.float64(1.099773),
#  'b2': np.float64(1.220246),
#  'b3': np.float64(1.272399),
#  'b4': np.float64(1.316624),
#  'b5': np.float64(1.358124),
#  'b6': np.float64(1.399821),
#  'b7': np.float64(1.444645),
#  'b8': np.float64(1.496496),
#  'b9': np.float64(1.565248),
#  'b10': np.float64(1.742986),
#  'AIA': np.float64(1.72),
#  'betaIA': np.float64(2.17),
#  'etaIA': np.float64(-0.41)}

# %%
param_labels={}
for ii, kk in enumerate(param_names[:5]):  # Only first 5 parameters
    param_labels[kk] = '$' + fish_photo['GCph-WL'].get_param_names_latex()[ii] + '$'
param_labels
# Out:
# {'Omegab': '$\\Omega_{{\\rm b}, 0}$',
#  'h': '$h$',
#  'ns': '$n_{\\rm s}$',
#  'sigma8': '$\\sigma_8$',
#  'Omegam': '$\\Omega_{{\\rm m}, 0}$'}

# %%
contour_plot = fco.make_triangle_plot(
    fishers=fishers_analyze.fisher_list,
    fisher_labels=['GCph', 'WL', 'GCph+WL'],
    params=param_names[:5], # Plot only first 5 parameters
    colors=snscolors[:3],
    truth_values=truth_values,
    smooth=10,
    bins=15,
    param_labels=param_labels,
    savefile='./results/photometric_probes_triangle.png'
)
# Out:
# Plot saved to: ./results/photometric_probes_triangle.png
